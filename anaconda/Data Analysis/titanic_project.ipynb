# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Preprocessing

# %%
df = pd.read_csv('t2.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         1       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         1       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.394737    2.265550   30.272590    0.447368
# std     120.810458    0.489380    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.nunique()
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
df.shape
# Out:
# (418, 12)

# %% [markdown]
# Renaming the columns

# %%
df.columns=["id","survived","class",'name',"gender","age","siblings","parch","ticket","fare","cabin","location"]
df
# Out:
#        id  survived  class                                          name  \
# 0     892         1      3                              Kelly, Mr. James
# 1     893         1      3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0      2                     Myles, Mr. Thomas Francis
# 3     895         0      3                              Wirz, Mr. Albert
# 4     896         1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...    ...                                           ...
# 413  1305         0      3                            Spector, Mr. Woolf
# 414  1306         1      1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0      3                  Saether, Mr. Simon Sivertsen
# 416  1308         0      3                           Ware, Mr. Frederick
# 417  1309         1      3                      Peter, Master. Michael J
#
#      gender   age  siblings  parch              ticket      fare cabin  \
# 0      male  34.5         0      0              330911    7.8292   NaN
# 1    female  47.0         1      0              363272    7.0000   NaN
# 2      male  62.0         0      0              240276    9.6875   NaN
# 3      male  27.0         0      0              315154    8.6625   NaN
# 4    female  22.0         1      1             3101298   12.2875   NaN
# ..      ...   ...       ...    ...                 ...       ...   ...
# 413    male   NaN         0      0           A.5. 3236    8.0500   NaN
# 414  female  39.0         0      0            PC 17758  108.9000  C105
# 415    male  38.5         0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 416    male   NaN         0      0              359309    8.0500   NaN
# 417    male   NaN         1      1                2668   22.3583   NaN
#
#     location
# 0          Q
# 1          S
# 2          Q
# 3          S
# 4          S
# ..       ...
# 413        S
# 414        C
# 415        S
# 416        S
# 417        C
#
# [418 rows x 12 columns]

# %%
df.isnull()  #(true for null) , if opposite we take notnul
# Out:
#         id  survived  class   name  gender    age  siblings  parch  ticket  \
# 0    False     False  False  False   False  False     False  False   False
# 1    False     False  False  False   False  False     False  False   False
# 2    False     False  False  False   False  False     False  False   False
# 3    False     False  False  False   False  False     False  False   False
# 4    False     False  False  False   False  False     False  False   False
# ..     ...       ...    ...    ...     ...    ...       ...    ...     ...
# 413  False     False  False  False   False   True     False  False   False
# 414  False     False  False  False   False  False     False  False   False
# 415  False     False  False  False   False  False     False  False   False
# 416  False     False  False  False   False   True     False  False   False
# 417  False     False  False  False   False   True     False  False   False
#
#       fare  cabin  location
# 0    False   True     False
# 1    False   True     False
# 2    False   True     False
# 3    False   True     False
# 4    False   True     False
# ..     ...    ...       ...
# 413  False   True     False
# 414  False  False     False
# 415  False   True     False
# 416  False   True     False
# 417  False   True     False
#
# [418 rows x 12 columns]

# %%
df.isnull().sum()  #gives sum of all true values
# Out:
# id            0
# survived      0
# class         0
# name          0
# gender        0
# age          86
# siblings      0
# parch         0
# ticket        0
# fare          1
# cabin       327
# location      0
# dtype: int64

# %% [markdown]
#  we see null values more in age and cabin

# %%
df.isnull().sum().sum()  #to get total number of null values
# Out:
# 414

# %%
df['cabin'].isnull()     #gives true if value=null
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 413     True
# 414    False
# 415     True
# 416     True
# 417     True
# Name: cabin, Length: 418, dtype: bool

# %%
df[df['cabin'].isnull()]   #to get null value rows in cabin column
# Out:
#        id  survived  class                                          name  \
# 0     892         1      3                              Kelly, Mr. James
# 1     893         1      3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0      2                     Myles, Mr. Thomas Francis
# 3     895         0      3                              Wirz, Mr. Albert
# 4     896         1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...    ...                                           ...
# 412  1304         1      3                Henriksson, Miss. Jenny Lovisa
# 413  1305         0      3                            Spector, Mr. Woolf
# 415  1307         0      3                  Saether, Mr. Simon Sivertsen
# 416  1308         0      3                           Ware, Mr. Frederick
# 417  1309         1      3                      Peter, Master. Michael J
#
#      gender   age  siblings  parch              ticket     fare cabin location
# 0      male  34.5         0      0              330911   7.8292   NaN        Q
# 1    female  47.0         1      0              363272   7.0000   NaN        S
# 2      male  62.0         0      0              240276   9.6875   NaN        Q
# 3      male  27.0         0      0              315154   8.6625   NaN        S
# 4    female  22.0         1      1             3101298  12.2875   NaN        S
# ..      ...   ...       ...    ...                 ...      ...   ...      ...
# 412  female  28.0         0      0              347086   7.7750   NaN        S
# 413    male   NaN         0      0           A.5. 3236   8.0500   NaN        S
# 415    male  38.5         0      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416    male   NaN         0      0              359309   8.0500   NaN        S
# 417    male   NaN         1      1                2668  22.3583   NaN        C
#
# [327 rows x 12 columns]

# %% [markdown]
# *  Custom Loop created to find the percentage of null values in each column

# %%
# percentage of null values 

for i in df.columns:
    if df[i].isnull().sum():
        print(f"Percentage of null values in {i} : {(df[i].isnull().sum()/len(df))*100}")
# Out:
# Percentage of null values in age : 20.574162679425836
# Percentage of null values in fare : 0.23923444976076555
# Percentage of null values in cabin : 78.22966507177034

# %%
null_percent = (df.isnull().sum() / len(df)) * 100

null_percent = null_percent[null_percent > 0]

plt.pie(null_percent,labels=null_percent.index, autopct='%0.2f%%',explode=[0,1,0],shadow=True)
plt.title('Percentage of Non-Null Values in Each Column')
plt.show()

# %%
null_counts = df.isnull().sum()

# bar plot
plt.bar(df.columns, null_counts)
plt.xlabel('Columns')
plt.ylabel('Number of Null Values')
plt.title('Count of Null Values in Each Column')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * Dropping Cabin Column as there are so many null values in Cabin
# * we can adjust age column with mean values/scaling later

# %%
df.drop('cabin',axis=1,inplace=True)
df
# Out:
#        id  survived  class                                          name  \
# 0     892         1      3                              Kelly, Mr. James
# 1     893         1      3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0      2                     Myles, Mr. Thomas Francis
# 3     895         0      3                              Wirz, Mr. Albert
# 4     896         1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...    ...                                           ...
# 413  1305         0      3                            Spector, Mr. Woolf
# 414  1306         1      1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0      3                  Saether, Mr. Simon Sivertsen
# 416  1308         0      3                           Ware, Mr. Frederick
# 417  1309         1      3                      Peter, Master. Michael J
#
#      gender   age  siblings  parch              ticket      fare location
# 0      male  34.5         0      0              330911    7.8292        Q
# 1    female  47.0         1      0              363272    7.0000        S
# 2      male  62.0         0      0              240276    9.6875        Q
# 3      male  27.0         0      0              315154    8.6625        S
# 4    female  22.0         1      1             3101298   12.2875        S
# ..      ...   ...       ...    ...                 ...       ...      ...
# 413    male   NaN         0      0           A.5. 3236    8.0500        S
# 414  female  39.0         0      0            PC 17758  108.9000        C
# 415    male  38.5         0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male   NaN         0      0              359309    8.0500        S
# 417    male   NaN         1      1                2668   22.3583        C
#
# [418 rows x 11 columns]

# %%
# df[df.isnull().any(axis=1)]
df.isnull().sum()
# Out:
# id           0
# survived     0
# class        0
# name         0
# gender       0
# age         86
# siblings     0
# parch        0
# ticket       0
# fare         1
# location     0
# dtype: int64

# %%
# df.dropna() #by default removes any row which contains null value - not needed currently
df[df["fare"].isnull()]  #to get the sigle row where fare=null
# Out:
#        id  survived  class                name gender   age  siblings  parch  \
# 152  1044         0      3  Storey, Mr. Thomas   male  60.5         0      0
#
#     ticket  fare location
# 152   3701   NaN        S

# %%
df['fare'].fillna(df['fare'].mean(),inplace=True)
df.isnull().sum()
# Out:
# id           0
# survived     0
# class        0
# name         0
# gender       0
# age         86
# siblings     0
# parch        0
# ticket       0
# fare         0
# location     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

print(df[['age']]) #2d data frame - imputer takes this
print(df['age'])   #1d array
# Out:
#       age
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# ..    ...
# 413   NaN
# 414  39.0
# 415  38.5
# 416   NaN
# 417   NaN
#
# [418 rows x 1 columns]
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: age, Length: 418, dtype: float64

# %%
imputer=SimpleImputer(strategy="mean")  #object for class
df["age"]=imputer.fit_transform(df[["age"]])

# %%
df.isnull().sum()
# Out:
# id          0
# survived    0
# class       0
# name        0
# gender      0
# age         0
# siblings    0
# parch       0
# ticket      0
# fare        0
# location    0
# dtype: int64

# %% [markdown]
# ### 1.Query show distribution of gender

# %%
df["gender"].value_counts() # to get counts of each unique group
# Out:
# male      266
# female    152
# Name: gender, dtype: int64

# %%
gen=df["gender"].value_counts()
plt.pie(gen,labels=gen.index,explode=[0.1,0],shadow=True,autopct="%0.2f%%")
plt.title("male and female population")
plt.legend()
plt.show()

# %% [markdown]
# #### Survival vs gender plot

# %%
df["survived"].value_counts()
# Out:
# 0    253
# 1    165
# Name: survived, dtype: int64

# %%
plt.pie(df["survived"].value_counts(),labels=['dead','alive'],autopct="%.2f%%",explode=[0.1,0],colors=['r','g'])
plt.title("Distribution")
plt.show()

# %%
sns.countplot(x='survived', data=df) 
# plt.bar(['Dead', 'Alive'],df["survived"].value_counts())
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Survived Bar Graph')
plt.show()

# %% [markdown]
# ### *  Among males how many survived , among females how many survived?

# %%
g=df.groupby("gender")["survived"].value_counts()
g
# Out:
# gender  survived
# female  1           141
#         0            11
# male    0           242
#         1            24
# Name: survived, dtype: int64

# %%
g.values
# Out:
# array([141,  11, 242,  24], dtype=int64)

# %%
f=len(df[df['gender']=='female'])
m=len(df[df['gender']=='male'])
print(f"Percentage of female survivors = {g[0]/f*100}")
print(f"Percentage of female death = {g[1]/f*100}")
print(f"Percentage of male survivors = {g[-1]/m*100}")
print(f"Percentage of male death = {g[2]/m*100}")
# Out:
# Percentage of female survivors = 92.76315789473685
# Percentage of female death = 7.236842105263158
# Percentage of male survivors = 9.022556390977442
# Percentage of male death = 90.97744360902256

# %%
sns.countplot(x='survived', data=df,hue="gender") #creates bar graph
plt.xlabel('0- Dead 1-Alive')
plt.ylabel('Count')
plt.title('Survived Bar Graph')
plt.show()

# %%
df
# Out:
#        id  survived  class                                          name  \
# 0     892         1      3                              Kelly, Mr. James
# 1     893         1      3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0      2                     Myles, Mr. Thomas Francis
# 3     895         0      3                              Wirz, Mr. Albert
# 4     896         1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...    ...                                           ...
# 413  1305         0      3                            Spector, Mr. Woolf
# 414  1306         1      1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0      3                  Saether, Mr. Simon Sivertsen
# 416  1308         0      3                           Ware, Mr. Frederick
# 417  1309         1      3                      Peter, Master. Michael J
#
#      gender       age  siblings  parch              ticket      fare location
# 0      male  34.50000         0      0              330911    7.8292        Q
# 1    female  47.00000         1      0              363272    7.0000        S
# 2      male  62.00000         0      0              240276    9.6875        Q
# 3      male  27.00000         0      0              315154    8.6625        S
# 4    female  22.00000         1      1             3101298   12.2875        S
# ..      ...       ...       ...    ...                 ...       ...      ...
# 413    male  30.27259         0      0           A.5. 3236    8.0500        S
# 414  female  39.00000         0      0            PC 17758  108.9000        C
# 415    male  38.50000         0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  30.27259         0      0              359309    8.0500        S
# 417    male  30.27259         1      1                2668   22.3583        C
#
# [418 rows x 11 columns]

# %% [markdown]
# ###  2. Query to replace something  (can also use rename method)

# %%
df.loc[df["gender"]=='male',"gender"]="m"  #loc is label based, while iloc is integer based, but both can take boolean
df
# Out:
#        id  survived  class                                          name  \
# 0     892         1      3                              Kelly, Mr. James
# 1     893         1      3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0      2                     Myles, Mr. Thomas Francis
# 3     895         0      3                              Wirz, Mr. Albert
# 4     896         1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...    ...                                           ...
# 413  1305         0      3                            Spector, Mr. Woolf
# 414  1306         1      1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0      3                  Saether, Mr. Simon Sivertsen
# 416  1308         0      3                           Ware, Mr. Frederick
# 417  1309         1      3                      Peter, Master. Michael J
#
#      gender       age  siblings  parch              ticket      fare location
# 0         m  34.50000         0      0              330911    7.8292        Q
# 1    female  47.00000         1      0              363272    7.0000        S
# 2         m  62.00000         0      0              240276    9.6875        Q
# 3         m  27.00000         0      0              315154    8.6625        S
# 4    female  22.00000         1      1             3101298   12.2875        S
# ..      ...       ...       ...    ...                 ...       ...      ...
# 413       m  30.27259         0      0           A.5. 3236    8.0500        S
# 414  female  39.00000         0      0            PC 17758  108.9000        C
# 415       m  38.50000         0      0  SOTON/O.Q. 3101262    7.2500        S
# 416       m  30.27259         0      0              359309    8.0500        S
# 417       m  30.27259         1      1                2668   22.3583        C
#
# [418 rows x 11 columns]

# %%
df.iloc[df["gender"]=='m',4]='male'
df
# Out:
#        id  survived  class                                          name  \
# 0     892         1      3                              Kelly, Mr. James
# 1     893         1      3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0      2                     Myles, Mr. Thomas Francis
# 3     895         0      3                              Wirz, Mr. Albert
# 4     896         1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...    ...                                           ...
# 413  1305         0      3                            Spector, Mr. Woolf
# 414  1306         1      1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0      3                  Saether, Mr. Simon Sivertsen
# 416  1308         0      3                           Ware, Mr. Frederick
# 417  1309         1      3                      Peter, Master. Michael J
#
#      gender       age  siblings  parch              ticket      fare location
# 0      male  34.50000         0      0              330911    7.8292        Q
# 1    female  47.00000         1      0              363272    7.0000        S
# 2      male  62.00000         0      0              240276    9.6875        Q
# 3      male  27.00000         0      0              315154    8.6625        S
# 4    female  22.00000         1      1             3101298   12.2875        S
# ..      ...       ...       ...    ...                 ...       ...      ...
# 413    male  30.27259         0      0           A.5. 3236    8.0500        S
# 414  female  39.00000         0      0            PC 17758  108.9000        C
# 415    male  38.50000         0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  30.27259         0      0              359309    8.0500        S
# 417    male  30.27259         1      1                2668   22.3583        C
#
# [418 rows x 11 columns]

# %% [markdown]
# ### 3. Query for Searching a record using parameter any value

# %%
s = input().strip()  

try:
    s = int(s) if s.isdigit() else float(s)
except ValueError:
    pass


df[df.eq(s).any(axis=1)]
# Out:
# Kelly, Mr. James
#     id  survived  class              name gender   age  siblings  parch  \
# 0  892         1      3  Kelly, Mr. James   male  34.5         0      0
#
#      fare location
# 0  7.8292        Q

# %% [markdown]
# ### 4.  Fares vs Class

# %%
plt.scatter(df['class'], df['fare'])
plt.xlabel('Class')
plt.ylabel('Fares')
plt.title('Fares by Class')
plt.show()

# %%
df.groupby('class')['fare'].mean()
# Out:
# class
# 1    94.280297
# 2    22.202104
# 3    12.565951
# Name: fare, dtype: float64

# %%
average_fare = df.groupby('class')['fare'].mean()

plt.bar(average_fare.index, average_fare.values)
plt.xlabel('Class')
plt.ylabel('Average Fare')
plt.title('Average Fare by Class')
plt.show()

# %%
sns.catplot(y='fare',x='class',data=df)
plt.title("fare vs class")
# Out:
# Text(0.5, 1.0, 'fare vs class')

# %% [markdown]
# ### 5. what ages survived most ?

# %%
survived = df[df['survived'] == 1]['age']
not_survived = df[df['survived'] == 0]['age']

plt.hist(survived,alpha=1, label='Survived')
plt.hist(not_survived,alpha=0.8, label='Not Survived')

plt.xlabel('Age')
plt.ylabel('Count')
plt.legend()
plt.title('Age Distribution for Survived and Not Survived')
plt.show()

# %%
sns.kdeplot(data=df, x='age', hue='survived')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ### 6. Which class and gender survived

# %%
sns.catplot(x='class', hue='gender', col='survived', data=df, kind='count', height=5 )

# %% [markdown]
# ### 7. Number of people Age> 60?

# %%
df[df['age']>60]
# Out:
#        id  survived  class                                               name  \
# 2     894         0      2                          Myles, Mr. Thomas Francis
# 13    905         0      2                               Howard, Mr. Benjamin
# 81    973         1      1                                 Straus, Mr. Isidor
# 96    988         1      1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 114  1006         1      1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 142  1034         0      1                         Ryerson, Mr. Arthur Larned
# 152  1044         0      3                                 Storey, Mr. Thomas
# 179  1071         1      1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 193  1085         0      2                                  Lingane, Mr. John
# 236  1128         0      1                           Warren, Mr. Frank Manley
# 305  1197         1      1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
#
#      gender   age  siblings  parch    ticket        fare location
# 2      male  62.0         0      0    240276    9.687500        Q
# 13     male  63.0         1      0     24065   26.000000        S
# 81     male  67.0         1      0  PC 17483  221.779200        S
# 96   female  76.0         1      0     19877   78.850000        S
# 114  female  63.0         1      0  PC 17483  221.779200        S
# 142    male  61.0         1      3  PC 17608  262.375000        C
# 152    male  60.5         0      0      3701   35.627188        S
# 179  female  64.0         0      2  PC 17756   83.158300        C
# 193    male  61.0         0      0    235509   12.350000        Q
# 236    male  64.0         1      0    110813   75.250000        C
# 305  female  64.0         1      1    112901   26.550000        S

# %%
len(df[df['age']>60])
# Out:
# 11

# %% [markdown]
# ###  8. Youngest and Oldest?

# %%
df[df['age']==df['age'].min()]
# Out:
#        id  survived  class                                     name  gender  \
# 354  1246         1      3  Dean, Miss. Elizabeth Gladys Millvina""  female
#
#       age  siblings  parch     ticket    fare location
# 354  0.17         1      2  C.A. 2315  20.575        S

# %%
df[df['age']==df['age'].max()]
# Out:
#      id  survived  class                                               name  \
# 96  988         1      1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#     gender   age  siblings  parch ticket   fare location
# 96  female  76.0         1      0  19877  78.85        S

# %% [markdown]
# ### 9. Total Fare Collected on Ship?

# %%
df['fare'].sum()
# Out:
# 14892.164788489208

# %% [markdown]
# ### 10. Age Distribution graph more clear

# %%
sns.histplot(data=df,x='age',bins=30); # more bins=more divisions

# %%
df["age"].mean()
# Out:
# 30.272590361445815

# %%
sns.boxplot(data=df,x='class',y='age')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# ### 11. Name Start with a letter

# %%
df[df['name'].str.startswith('P')]
# Out:
#        id  survived  class                                    name  gender  \
# 45    937         0      3         Peltomaki, Mr. Nikolai Johannes    male
# 51    943         0      2                      Pulbaum, Mr. Franz    male
# 91    983         0      3                      Pedersen, Mr. Olaf    male
# 129  1021         0      3                    Petersen, Mr. Marius    male
# 159  1051         1      3     Peacock, Mrs. Benjamin (Edith Nile)  female
# 163  1055         0      3                      Pearce, Mr. Ernest    male
# 164  1056         0      2           Peruschitz, Rev. Joseph Maria    male
# 186  1078         1      2    Phillips, Miss. Alice Frances Louisa  female
# 264  1156         0      2  Portaluppi, Mr. Emilio Ilario Giuseppe    male
# 269  1161         0      3                       Pokrnic, Mr. Mate    male
# 276  1168         0      2            Parker, Mr. Clifford Richard    male
# 281  1173         0      3          Peacock, Master. Alfred Edward    male
# 302  1194         0      2             Phillips, Mr. Escott Robert    male
# 303  1195         0      3                       Pokrnic, Mr. Tome    male
# 369  1261         0      2           Pallas y Castello, Mr. Emilio    male
# 389  1281         0      3             Palsson, Master. Paul Folke    male
# 390  1282         0      1              Payne, Mr. Vivian Ponsonby    male
# 409  1301         1      3               Peacock, Miss. Treasteall  female
# 417  1309         1      3                Peter, Master. Michael J    male
#
#           age  siblings  parch              ticket     fare location
# 45   25.00000         0      0   STON/O 2. 3101291   7.9250        S
# 51   27.00000         0      0       SC/PARIS 2168  15.0333        C
# 91   30.27259         0      0              345498   7.7750        S
# 129  24.00000         0      0              342441   8.0500        S
# 159  26.00000         0      2  SOTON/O.Q. 3101315  13.7750        S
# 163  30.27259         0      0              343271   7.0000        S
# 164  41.00000         0      0              237393  13.0000        S
# 186  21.00000         0      1         S.O./P.P. 2  21.0000        S
# 264  30.00000         0      0          C.A. 34644  12.7375        C
# 269  17.00000         0      0              315095   8.6625        S
# 276  28.00000         0      0            SC 14888  10.5000        S
# 281   0.75000         1      1  SOTON/O.Q. 3101315  13.7750        S
# 302  43.00000         0      1         S.O./P.P. 2  21.0000        S
# 303  24.00000         0      0              315092   8.6625        S
# 369  29.00000         0      0       SC/PARIS 2147  13.8583        C
# 389   6.00000         3      1              349909  21.0750        S
# 390  23.00000         0      0               12749  93.5000        S
# 409   3.00000         1      1  SOTON/O.Q. 3101315  13.7750        S
# 417  30.27259         1      1                2668  22.3583        C

# %% [markdown]
# ### 12. Draw pairplot and Corelation

# %%
df.drop('ticket',axis=1,inplace=True)
df
# Out:
#        id  survived  class                                          name  \
# 0     892         1      3                              Kelly, Mr. James
# 1     893         1      3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0      2                     Myles, Mr. Thomas Francis
# 3     895         0      3                              Wirz, Mr. Albert
# 4     896         1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...    ...                                           ...
# 413  1305         0      3                            Spector, Mr. Woolf
# 414  1306         1      1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0      3                  Saether, Mr. Simon Sivertsen
# 416  1308         0      3                           Ware, Mr. Frederick
# 417  1309         1      3                      Peter, Master. Michael J
#
#      gender       age  siblings  parch      fare location
# 0      male  34.50000         0      0    7.8292        Q
# 1    female  47.00000         1      0    7.0000        S
# 2      male  62.00000         0      0    9.6875        Q
# 3      male  27.00000         0      0    8.6625        S
# 4    female  22.00000         1      1   12.2875        S
# ..      ...       ...       ...    ...       ...      ...
# 413    male  30.27259         0      0    8.0500        S
# 414  female  39.00000         0      0  108.9000        C
# 415    male  38.50000         0      0    7.2500        S
# 416    male  30.27259         0      0    8.0500        S
# 417    male  30.27259         1      1   22.3583        C
#
# [418 rows x 10 columns]

# %%
sns.pairplot(df.iloc[:,1:])

# %%
sns.pairplot(df.iloc[:,1:],hue="gender",palette="bright")

# %%
print(df.corr())  #gives pearson corelation coefficient
# Out:
#                 id  survived     class       age  siblings     parch      fare
# id        1.000000 -0.052872 -0.026751 -0.030874  0.003818  0.043080  0.008209
# survived -0.052872  1.000000 -0.074599  0.000232  0.082972  0.121145  0.123488
# class    -0.026751 -0.074599  1.000000 -0.440782  0.001087  0.018721 -0.576619
# age      -0.030874  0.000232 -0.440782  1.000000 -0.079535 -0.045073  0.326800
# siblings  0.003818  0.082972  0.001087 -0.079535  1.000000  0.306895  0.171488
# parch     0.043080  0.121145  0.018721 -0.045073  0.306895  1.000000  0.230001
# fare      0.008209  0.123488 -0.576619  0.326800  0.171488  0.230001  1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>
